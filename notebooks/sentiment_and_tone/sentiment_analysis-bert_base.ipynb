# %% [markdown]
# # Set up huggingface

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 665kB 2.8MB/s
# ...
#      |████████████████████████████████| 1.1MB 14.1MB/s
# ...
#      |████████████████████████████████| 890kB 18.5MB/s
# ...
#      |████████████████████████████████| 3.8MB 24.3MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=78c71d74c70b2a07519e0e106721f78587a279ad6e5fc1e5459a445f9e6409b1
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...

# %% [markdown]
# # Sentiment analysis

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

pretrained_model_name = "nlptown/bert-base-multilingual-uncased-sentiment"

tokenizer = AutoTokenizer.from_pretrained(pretrained_model_name)
model = AutoModelForSequenceClassification.from_pretrained(pretrained_model_name)

# %%
from transformers import pipeline

sentiment_pipeline = pipeline("sentiment-analysis")

# %%
print(sentiment_pipeline("Here is an example sentence."))
print(sentiment_pipeline("Here is an example sentence!"))
print(sentiment_pipeline("neutral"))
# Out:
# [{'label': 'NEGATIVE', 'score': 0.6662097573280334}]
# [{'label': 'POSITIVE', 'score': 0.7462076544761658}]
# [{'label': 'NEGATIVE', 'score': 0.9992249011993408}]
