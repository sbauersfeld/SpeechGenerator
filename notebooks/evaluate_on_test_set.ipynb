# %% [markdown]
# # General Imports and Utilities

# %%
import os
import datetime

def quote(t):
    return '"{}"'.format(t)

# %% [markdown]
# # Model Evaluation
#
# This notebook computes perplexity and performs text generation to evaluate our models.

# %%
GDRIVE_MOUNT_PATH = '/content/gdrive'
NLP_DRIVE_PATH = os.path.join(GDRIVE_MOUNT_PATH, 'Shared drives/CS263')

# EXP_PARENT_DIR points to the directory where all experiments are stored. Can be updated.
EXP_PARENT_DIR = os.path.join(NLP_DRIVE_PATH, "models/american_rhetoric")

# TODO: change this as necessary before each experiment
EXP_NAME = "tones_watson-summarized_bart_large_xsm/converted-summary_tone-tag_v3-eos-cls"
EXP_DIR = os.path.join(EXP_PARENT_DIR, EXP_NAME) # Points to the current experiment dir

# TODO: Update this to point to your desired dataset
DATASET_DIR = os.path.join(NLP_DRIVE_PATH, 'data/american_rhetoric/speech_bank/tones_watson-summarized_bart_large_xsm/converted-summary_tone')

OUTPUT_DIR = quote(os.path.join(EXP_DIR, 'eval_output'))
OUTPUT_DIR_TRAIN = quote(os.path.join(EXP_DIR, 'output_train'))
OUTPUT_DIR_VAL = quote(os.path.join(EXP_DIR, 'output_val'))
OUTPUT_DIR_TEST = quote(os.path.join(EXP_DIR, 'output_test'))

# TRAIN_DATA = os.path.join(DATASET_DIR, 'parsed-summarized-converted-train.txt')
# EVAL_DATA = os.path.join(DATASET_DIR, 'parsed-summarized-converted-val.txt')
# TEST_DATA = os.path.join(DATASET_DIR, 'parsed-summarized-converted-test.txt')

TRAIN_DATA = os.path.join(DATASET_DIR, 'data-train.txt')
EVAL_DATA = os.path.join(DATASET_DIR, 'data-val.txt')
TEST_DATA = os.path.join(DATASET_DIR, 'data-test.txt')

TRAIN_DATA_PATH=quote(TRAIN_DATA)
EVAL_DATA_PATH=quote(EVAL_DATA)
TEST_DATA_PATH=quote(TEST_DATA)

MODEL_TYPE="gpt2-medium" # The type of model we are using
CHECKPOINT = os.path.join(EXP_DIR, "output")
# CHECKPOINT=os.path.join(NLP_DRIVE_PATH, "models/american_rhetoric/tones_watson-summarized_bart_large_xsm/converted-summary_tone/output") # location of saved weights
# CHECKPOINT=os.path.join(NLP_DRIVE_PATH, "models/american_rhetoric/tones_watson-summarized_bart_large_xsm/converted-summary_tone/output/checkpoint-5000") # location of saved weights
CHECKPOINT_PATH=quote(CHECKPOINT) # same as above but with double quotes for bash


TOKENIZER = os.path.join(EXP_DIR, "tokenizer")
TOKENIZER_PATH = quote(TOKENIZER)

# %%
print(GDRIVE_MOUNT_PATH)
print(NLP_DRIVE_PATH)
print(EXP_PARENT_DIR)
print(EXP_NAME)
print(EXP_DIR)
print(DATASET_DIR)

print(OUTPUT_DIR)
print(OUTPUT_DIR_TRAIN)
print(OUTPUT_DIR_TEST)
print(OUTPUT_DIR_VAL)


print(TRAIN_DATA)
print(EVAL_DATA)
print(TEST_DATA)

print(TRAIN_DATA_PATH)
print(EVAL_DATA_PATH)
print(TEST_DATA_PATH)

print(MODEL_TYPE)
print(CHECKPOINT)
print(CHECKPOINT_PATH)
# Out:
# /content/gdrive
# /content/gdrive/Shared drives/CS263
# /content/gdrive/Shared drives/CS263/models/american_rhetoric
# tones_watson-summarized_bart_large_xsm/converted-summary_tone-tag_v3-eos-cls
# /content/gdrive/Shared drives/CS263/models/american_rhetoric/tones_watson-summarized_bart_large_xsm/converted-summary_tone-tag_v3-eos-cls
# /content/gdrive/Shared drives/CS263/data/american_rhetoric/speech_bank/tones_watson-summarized_bart_large_xsm/converted-summary_tone
# "/content/gdrive/Shared drives/CS263/models/american_rhetoric/tones_watson-summarized_bart_large_xsm/converted-summary_tone-tag_v3-eos-cls/eval_output"
# "/content/gdrive/Shared drives/CS263/models/american_rhetoric/tones_watson-summarized_bart_large_xsm/converted-summary_tone-tag_v3-eos-cls/output_train"
# "/content/gdrive/Shared drives/CS263/models/american_rhetoric/tones_watson-summarized_bart_large_xsm/converted-summary_tone-tag_v3-eos-cls/output_test"
# "/content/gdrive/Shared drives/CS263/models/american_rhetoric/tones_watson-summarized_bart_large_xsm/converted-summary_tone-tag_v3-eos-cls/output_val"
# /content/gdrive/Shared drives/CS263/data/american_rhetoric/speech_bank/tones_watson-summarized_bart_large_xsm/converted-summary_tone/data-train.txt
# /content/gdrive/Shared drives/CS263/data/american_rhetoric/speech_bank/tones_watson-summarized_bart_large_xsm/converted-summary_tone/data-val.txt
# /content/gdrive/Shared drives/CS263/data/american_rhetoric/speech_bank/tones_watson-summarized_bart_large_xsm/converted-summary_tone/data-test.txt
# "/content/gdrive/Shared drives/CS263/data/american_rhetoric/speech_bank/tones_watson-summarized_bart_large_xsm/converted-summary_tone/data-train.txt"
# "/content/gdrive/Shared drives/CS263/data/american_rhetoric/speech_bank/tones_watson-summarized_bart_large_xsm/converted-summary_tone/data-val.txt"
# "/content/gdrive/Shared drives/CS263/data/american_rhetoric/speech_bank/tones_watson-summarized_bart_large_xsm/converted-summary_tone/data-test.txt"
# gpt2-medium
# /content/gdrive/Shared drives/CS263/models/american_rhetoric/tones_watson-summarized_bart_large_xsm/converted-summary_tone-tag_v3-eos-cls/output
# "/content/gdrive/Shared drives/CS263/models/american_rhetoric/tones_watson-summarized_bart_large_xsm/converted-summary_tone-tag_v3-eos-cls/output"

# %% [markdown]
# # Setup
#
# We still need the hugging face transformers library. Clone it here and install dependencies.

# %%
# remove the capture to show output from this cell
# %%capture

import os

# remove previous installations and clone the repo
# !rm -rm /content/transformers
# !git clone https://github.com/huggingface/transformers

# make sure all dependencies are installed
os.chdir('/content/transformers')

# !pip install .
# !pip install -r ./examples/requirements.txt

# navigate to folder with the language modeling training script
os.chdir('/content/transformers/examples/language-modeling')

# %%
# connect to google drive so we can access our data set
from google.colab import drive
drive.mount(GDRIVE_MOUNT_PATH)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# # Generate Text
#
# The next two blocks generate text based on the input prompt.

# %%
# comment the line below to show output from this cell
# %%capture log_load_model

# this cell just loads our pretrained model
from transformers import AutoConfig
from transformers import AutoTokenizer
from transformers import AutoModelWithLMHead
import torch

# config = AutoConfig.from_pretrained(TOKENIZER)
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER)

# model = AutoModelWithLMHead.from_pretrained(CHECKPOINT, config=config)
model = AutoModelWithLMHead.from_pretrained(CHECKPOINT)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# %%
log_load_model.show()
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50261, 1024)
#     (wpe): Embedding(1024, 1024)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (12): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (13): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (14): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (15): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (16): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (17): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (18): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (19): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (20): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (21): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (22): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (23): Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=1024, out_features=50261, bias=False)
# )

# %%
# change this prompt to get different speeches
# PROMPT = """
# <summary="Hospitals will need more personal protective equipment. The stock market is volatile. Everyone should adhere to social distancing and general hygiene to stay healthy.">
# <tone="fear, confident">
# """

PROMPT_v3 = """<|summary|>
Hospitals will need more personal protective equipment. The stock market is volatile. Everyone should adhere to social distancing and general hygiene to stay healthy.
<|tone|>
fear, confident
<|cls|>"""

# PROMPT_v3_from_test_data = """<|summary|>
# The United States Department of Education was created to protect the rights of all students, not just those who are victims of discrimination or who are accused of discrimination.
# <|tone|>
# analytical, joy, sadness
# <|cls|>"""

#PROMPT = PROMPT_v3_from_test_data
PROMPT = PROMPT_v3
print(PROMPT)

# MAX_LENGTH=512
MAX_LENGTH=1024
TOP_K=50
TOP_P=0.95
NUM_OUTPUTS=3

input_ids = tokenizer.encode(PROMPT, return_tensors="pt").to(device)

sample_outputs = model.generate(
    input_ids,
    do_sample=True, 
    max_length=MAX_LENGTH, 
    top_k=TOP_K, 
    top_p=TOP_P, 
    num_return_sequences=NUM_OUTPUTS,
    repetition_penalty=None,
    early_stopping=True
)

output_txt = ""
print("\n\nOutput:\n" + 50 * '-')
for i, sample_output in enumerate(sample_outputs):
  output_txt += "\n\n{}: {}".format(i, tokenizer.decode(sample_output, skip_special_tokens=True))

print(output_txt)

gen_file_name = datetime.datetime.now().strftime(
    "sample_generation-%Y_%m_%d-%H_%M_%S.txt"
)
with open(os.path.join(EXP_DIR, gen_file_name), "w") as fp:
  fp.writelines(output_txt)
# Out:
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# <|summary|>
# Hospitals will need more personal protective equipment. The stock market is volatile. Everyone should adhere to social distancing and general hygiene to stay healthy.
# <|tone|>
# fear, confident
# <|cls|>
#
#
# Output:
# --------------------------------------------------
#
#
# 0: <|summary|>
# Hospitals will need more personal protective equipment. The stock market is volatile. Everyone should adhere to social distancing and general hygiene to stay healthy. <|tone|>
# fear, confident
# My fellow citizens:
# Over the past year, we have had an outbreak of a potentially deadly coronavirus in West Africa. It was originally called COVID-19 or 'Coast-to-Coast-19', but is now called H5N1.
# Our health systems, from all regions and the globe, are at their best when we are all vigilant, and work together. At the same time, the health needs of our people and the needs of the global community remain extremely dire, and increasingly urgent.
# Therefore, this morning, following the request of the United States Agency for International Development, I have ordered the immediate deployment of all available resources to prevent and detect COVID-19 from its first outbreak in the Americas, which has been spread by air travel across Europe. It is important, however, that we also protect our own communities in Europe and the entire world.
# As you know, on 29 November, there were two new cases of COVID-19, one of a young girl in the Netherlands and another in Germany. On 30 December, the first case was diagnosed in Bulgaria, where we also confirmed the second infection with H5N1 -- an infection that originated in the Philippines.
# The first case and the second two were confirmed to have come from the Philippine area. The third case is in quarantine in Zagreb, and we are taking precautionary measures against transmission. It is too early to determine the extent of their infections, but one is being monitored closely.
# Of the 48 countries in Europe, more than 50% have been affected by the infection, including over 40 countries in Europe’s southern and eastern regions.
# In response to the first cases, as of Monday, 31 December, we have notified WHO, Health Ministry, and all relevant authorities of affected countries. And in addition, on 31 December, I will declare a national state of national emergency in the countries affected by COVID-19.
# For those citizens who were at risk of exposure to infected individuals, we have started to remove medical equipment from public places and workplaces. In countries affected by H5N1, we are taking necessary measures to protect health workers, as well as hospitals.
# Hospitals will need more personal protective equipment. The stock market is volatile. Everyone should adhere to social distancing and general hygiene to stay healthy.
# There is no single, easy answer. We do not know the exact nature of the virus or what level of risk people may face, and in this context, we will do our best to ensure that necessary measures are taken to protect people.
# However, at this time, it is important to note the urgency of the situation and the urgency of the need to prepare for the worst. As a first step, we need to reduce our daily travel from this continent and also, in the European area. This requires us to be on alert.
# On a similar note, I have ordered the immediate deployment of all available resources to prevent and detect COVID-19 from its first outbreak in the Americas, which has been spread by air travel across Europe.
# We have been using the WHO-WHO-ARS [World Health Organization Information Network] for almost a year to monitor cases, tracing contact tracing across Europe and Africa and coordinating our response across the globe. It is now clear that the first cases in Asia and the Philippines have now spread to three additional countries.
# This new virus poses an unprecedented threat to the health of all of us and is spreading at an unprecedented pace. We cannot afford to be complacent. We must make this momentous situation all the more serious.
# Today, I will call on all countries to step up their steps in taking immediate measures. That includes making essential decisions to move from public to non-public places, or from private to private facilities. I urge all countries to immediately take measures to reduce public travel.
# I would remind everybody that, because of this virus, we have launched an immediate investigation into all cases that have come into our country. This is our national emergency.
# My fellow citizens: The health situation in the Americas continues to be serious and our response will be robust, and we will continue to monitor it closely. We will also continue to continue our efforts to prepare for the worst, and respond accordingly.
# Thank you very much.
#
# 1: <|summary|>
# Hospitals will need more personal protective equipment. The stock market is volatile. Everyone should adhere to social distancing and general hygiene to stay healthy. <|tone|>
# fear, confident
# Thank you so much everybody.
# In a little while, I will be back in Houston to open the doors of a new facility. It’s going to be like the old facility, with a larger, more luxurious entrance.
# My fellow Americans, we will be going to a new and improved -- a new and improved hospital -- a facility which is going to be of the highest standard. It will be open for patients without problems to receive the medical care that we all require.
# Just a few weeks ago, our doctors and nurses are telling us that in the next 24 to 72 hours, the most serious cases of pneumonia and other serious cases will be identified and treated at our new facility.
# I have been asked several times during these last few days, why are we doing this and why should I do it? I answered this question to my wife and our three sons, who have been in constant contact with me in recent days. I told them our decision -- my decision was the only correct and logical one.
# We are now, finally, going home.
# This morning, I was deeply moved by the outpouring of love and support from the people of the American Hospital System in the United States, from their doctors, nurses, and other medical staff, to our first responders, volunteers, friends, and family. I thank you all for your support and prayers, and I look forward to traveling back to Texas for more visits in the coming days.
# Thank you again, and please follow me on all social media, Facebook, Twitter.
# Thank you so much.
# Thank you.
#
# 2: <|summary|>
# Hospitals will need more personal protective equipment. The stock market is volatile. Everyone should adhere to social distancing and general hygiene to stay healthy. <|tone|>
# fear, confident
# I've been thinking and thinking and thinking and thinking about this whole "you'll be fine" business for about 18 months. And I've been thinking that I was pretty darn fine the first few weeks and months here. And then I lost 30 pounds and my life changed. And that's when I took the plunge. That's when I decided I needed to go to the doctor.
# And I'm on that. I'm not going to lie to you and tell you that you're gonna be fine.
# And the fact of the matter is that as soon as you start to feel sick, it's not good for anybody. It causes your body to overheat. It causes you to contract infections. It causes you to become more susceptible to the infections you contract. The body loses control over its own body temperature, and in turn, you start losing body hair and becoming increasingly susceptible to infections, and as a result, people lose all the weight that they otherwise would have lost and the body starts losing a large amount of blood.
# But there are ways to control your temperature, and that's why you need to exercise. And those include:
# - Regular exercise, both in terms of weight training and weight management, and exercise in general.
# - Eating nutritious foods in a diet free of refined sugar, artificial sweeteners, and fatty foods.
# - Exercise in short bursts; and being in an indoor setting at night.
# - A good hydration system.
# - A healthy diet.
# - A good sleep schedule.
# That's why I’m so sorry to all the doctors and nurses out there, all the medical staff and all the patients out there, but they're -- your lives will change in very short order if they are not careful. And they don’t really know what kind of changes they’re going to be making. And the consequences will be pretty devastating, and that’s not their fault.
# And they need to be cautious because the diseases that have been seen in this country, including the most insidious, which are called coronavirus and diphtheria and pertussis and whooping cough, the ones that are increasing the most, because they’re starting to get more severe, they’re very serious and they’re not just in our hospitals. But they’re all over. I -- and it’s not just the American people, it’s the world. It’s spread by very, very, very, very little people. And we are facing an epidemic, and we need to be prepared.
# If this was your country, you wouldn’t be living where we’re living right now, let alone in our cities. But we just did a census in Chicago. They said that at our country’s busiest airports, we had over 300 cases a day that is up to this very second -- and then there is a lot of spread. And we need to be really careful about when we get to the next major outbreak. And it has started very, very suddenly. And because of the way we were born, there’s a real, genuine fear of it. And there are a lot of people here that were born in the '70s and they’re all trying to put a stop to it now.
# So it is a huge concern to me because -- because the risk of this virus is really high.
# So what I would say is this:
# - Don’t get too close. I have been here for nearly a year and half and a half, and I’m convinced that the risk is very, very low. We need to not only be vigilant, but we need to work so that we keep people that we treat on the front lines of the prevention and treatment that they need, and that’s what we’ve been doing in this country. And what I would like to say is the virus that’s been going around in our country has nothing to do with the food we eat, but everything to do with how we make our houses.
# This is a virus that is not going to just kill us, it’s not going to make us miserable; it’s not going to make anyone sick. And it’s not going to make this country a haven for terror or terrorists. It’s going to be a much, much different country. So we’re going to have to make certain that we protect ourselves, and that our families don’t need to be put in situations where they’re at risk. And I want all of us, all of our Americans and everyone in this room, every one of us here, to try to do everything we can to help get this

# %% [markdown]
# # Compute Perplexity
#
# We can use the transformers library to compute perplexity. Note that it might produce different scores from training if the block size is not set to the same value as the training phase.

# %%
# !python run_language_modeling.py \
    --output_dir=$OUTPUT_DIR_TRAIN \
    --model_type=$MODEL_TYPE \
    --model_name_or_path=$CHECKPOINT_PATH \
    --do_eval \
    --eval_data_file=$TRAIN_DATA_PATH

print("Train data perplexity complete")

# %%
# !python run_language_modeling.py \
    --output_dir=$OUTPUT_DIR_TEST \
    --model_type=$MODEL_TYPE \
    --model_name_or_path=$CHECKPOINT_PATH \
    --do_eval \
    --eval_data_file=$TEST_DATA_PATH

print("Test data perplexity complete")
